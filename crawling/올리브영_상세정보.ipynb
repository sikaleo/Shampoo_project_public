# %%
from selenium import webdriver  # 라이브러리(모듈) 가져오라
from selenium.webdriver import ActionChains as AC
from tqdm import tqdm
from tqdm import tqdm_notebook
import re
from time import sleep
import time
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys

# %%
url='http://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000128661&dispCatNo=1000001000400080001'
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
driver.find_element_by_css_selector('#buyInfo > a').click()
list_con = driver.find_element_by_css_selector('#artcInfo > dl:nth-child(7) > dd')
list_con.text

# %%
html_source
# Out:
# '<html lang="ko" class=" -webkit-"><head><script async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="http://www.oliveyoung.co.kr/pc-static-root/js//common/weblog/wl6.js"></script><script src="https://connect.facebook.net/signals/plugins/inferredEvents.js?v=2.9.4" async=""></script><script src="https://connect.facebook.net/signals/config/1926423667616265?v=2.9.4&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NF4R92W"></script><script type="text/javascript" async="" defer="" src="http://assets.recobell.io/rblc/js/rblc-apne1.min.js"></script><script src="http://rblogger-issuer-apne1.recobell.io/user/guid?callback=jsonp_5jx3ra8fwowyu9u" async=""></script>\n\t<meta charset="utf-8">\n\t<meta http-eq
# ...

# %%
# Out:
# '정제수, 다이소듐라우레스설포석시네이트, 라우릴하이드록시설테인, 코카마이드메틸엠이에이, 스타이렌/아크릴레이트코폴리머, 글리세린, 소듐코코일이세티오네이트, 바이오틴, 세라마이드엔피, 사발팜열매추출물, 판테놀, 아데노신, 카페익애씨드, 나이아신아마이드, 징크피리치온, 살리실릭애씨드, 바위돌꽃뿌리추출물, 참마뿌리추출물, 작약뿌리추출물, 생강추출물, 고삼추출물, 폴리쿼터늄-7, 피이지-120메틸글루코스디올리에이트, 프로판다이올, 소듐라우로일메틸아미노프로피오네이트, 에탄올, 피이지-45팜커넬글리세라이즈, C12-13알킬락테이트, 폴리쿼터늄-10, 세트리모늄클로라이드, 멘톨, 코카미도프로필베타인, 카프릴릴글라이콜, 소듐클로라이드, 소듐벤조에이트, 트라이하이드록시스테아린, 다이소듐이디티에이, 피이지-6카프릴릭/카프릭글리세라이즈, 에틸헥실글리세린, 징크클로라이드, 시트릭애씨드, 동백나무씨오일, 아르간커넬오일, 다이소듐포스페이트, 드럼스틱씨오일, 토코페롤, 레시틴, 카프릴릭/카프릭트라이글리세라이즈, 폴리솔베이트80, 1,2-헥산다이올, 향료'
